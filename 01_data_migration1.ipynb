# %% [markdown]
# ### Good Classes Finder
# Agenda
# 1. Find good classes with no error photos
# 2. Sample a few good classes and migrate their data to separate folder
#
# Issues:
# 1. [07/01/2019] Some image can't be opened e.g /home/r8user2/Documents/HY/dress_data/datasets/imgtrain/民族风连衣裙/Co6q4VrxcFSAaNmBAAJGVl-KaNU099.jpg
# > Causes: Some images are truncated https://stackoverflow.com/questions/12984426/python-pil-ioerror-image-file-truncated-with-big-images
#
# 2. [07/01/2019] Some images has only 2 dimension in nparray e.g /home/r8user2/Documents/HY/dress_data/datasets/imgtrain/民族风连衣裙/Co6q4VryEu6AEjzWAAFI4Sjx41c689.jpg
# > Cause:
#
# References:
# 1. multiprocessing for multi loops  https://stackoverflow.com/questions/40450661/parallelize-these-nested-for-loops-in-python
# 2. multiprocess for several arguments
# https://stackoverflow.com/questions/5442910/python-multiprocessing-pool-map-for-multiple-arguments

# %%
from collections import defaultdict
import os
import matplotlib.pyplot as plt
from PIL import Image
from PIL import ImageFile
# %matplotlib inline
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
SOURCE_PATH = '/home/r8user2/Documents/HY/dress_data/datasets/'
PARTITION_MAP = {1: 'imgtrain', 2: 'imgval', 3: 'imgtest'}

# %%
CLASS_MAP = {}
for id_, class_type in enumerate(os.listdir(SOURCE_PATH + 'imgtrain')):
    CLASS_MAP[id_] = class_type

# %% [markdown]
# #### Distribution of Partition of All Classes

# %%
dist_dict = defaultdict(dict)
for partition_idx, folder in PARTITION_MAP.items():
    for class_idx, class_ in CLASS_MAP.items():
        target_path = SOURCE_PATH + folder +'/' + class_
        cnt = len([item for item in os.listdir(target_path) if 'jpg' in item])
        dist_dict[partition_idx][class_idx] = cnt
        print('[%s/ %s]: %d' % (folder, class_, cnt))
# Out:
# [imgtrain/ 蝴蝶结长袖连衣裙]: 2978
# [imgtrain/ 包臀长袖连衣裙]: 2400
# [imgtrain/ 假两件连衣裙]: 2403
# [imgtrain/ 修身包臀连衣裙]: 2400
# [imgtrain/ 女童背心裙]: 2398
# [imgtrain/ 刺绣连衣裙]: 2395
# [imgtrain/ 修身打底连衣裙]: 2399
# [imgtrain/ 礼服长裙]: 2400
# [imgtrain/ 包臀鱼尾裙]: 2402
# [imgtrain/ 提花连衣裙]: 2359
# [imgtrain/ 民族风旗袍]: 2408
# [imgtrain/ 字母连衣裙]: 2401
# [imgtrain/ 大码宽松连衣裙]: 2403
# [imgtrain/ 桑蚕丝裙子]: 2400
# [imgtrain/ 高腰连衣裙]: 2401
# [imgtrain/ 圆点连衣裙]: 2400
# [imgtrain/ 公主蓬蓬裙]: 2400
# [imgtrain/ 假两件裙子]: 2399
# [imgtrain/ 蕾丝连衣裙]: 2400
# [imgtrain/ 勾花连衣裙]: 2400
# [imgtrain/ 大码短袖连衣裙]: 2399
# [imgtrain/ 松紧腰连衣裙]: 2396
# [imgtrain/ 半身裙套装]: 2400
# [imgtrain/ 连衣裙两件套]: 2401
# [imgtrain/ 复古旗袍]: 2392
# [imgtrain/ 网纱长裙]: 2402
# [imgtrain/ 潮流连衣裙]: 2400
# [imgtrain/ 包臀针织连衣裙]: 2397
# [imgtrain/ 连帽连衣裙]: 2400
# [imgtrain/ 品牌连衣裙]: 2400
# [imgtrain/ 无袖长裙]: 2400
# [imgtrain/ 长袖针织衫]: 2404
# [imgtrain/ 牛仔连衣裙]: 2402
# [imgtrain/ 两件套装裙]: 2401
# [imgtrain/ 修身打底裙]: 2392
# [imgtrain/ 女童礼服]: 2398
# [imgtrain/ 女童长袖连衣裙]: 2400
# [imgtrain/ 套头连衣裙]: 2406
# [imgtrain/ 简约连衣裙]: 2398
# [imgtrain/ 蕾丝打底连衣裙]: 2401
# [imgtrain/ 立领连衣裙]: 1046
# [imgtrain/ 绑带连衣裙]: 2401
# [imgtrain/ 圆领连衣裙]: 2403
# [imgtrain/ 长袖连衣裙]: 2401
# [imgtrain/ 短款旗袍]: 2396
# [imgtrain/ 刺绣旗袍]: 2400
# [imgtrain/ 桑蚕丝连衣裙]: 2404
# [imgtrain/ 绷带连衣裙]: 2398
# [imgtrain/ 圆领a字裙]: 2401
# [imgtrain/ 休闲连衣裙]: 2400
# [imgtrain/ 短袖长裙]: 2413
# [imgtrain/ 长袖印花连衣裙]: 2373
# [imgtrain/ 宽松连衣裙]: 2401
# [imgtrain/ 吊带两件套]: 2400
# [imgtrain/ 波点连衣裙]: 2353
# [imgtrain/ 女童旗袍]: 2397
# [imgtrain/ 印花裙子]: 2375
# [imgtrain/ 女童公主裙]: 2408
# [imgtrain/ 蕾丝公主裙]: 2400
# [imgtrain/ 钉珠连衣裙]: 2401
# [imgtrain/ 复古连衣裙]: 2161
# [imgtrain/ 女童礼服裙]: 2401
# [imgtrain/ 镂空连衣裙]: 2401
# [imgtrain/ 波西米亚长裙]: 2390
# [imgtrain/ 公主连衣裙]: 2400
# [imgtrain/ 沙滩连衣裙]: 2400
# [imgtrain/ 露肩连衣裙]: 2400
# [imgtrain/ 翻领连衣裙]: 2400
# [imgtrain/ 大码连衣裙]: 2396
# [imgtrain/ 花朵连衣裙]: 2400
# [imgtrain/ 碎花连衣裙]: 2101
# [imgtrain/ 哺乳连衣裙]: 2389
# [imgtrain/ 灯笼袖连衣裙]: 2401
# [imgtrain/ 公主裙子]: 2398
# [imgtrain/ 加厚打底连衣裙]: 2400
# [imgtrain/ 大码长袖连衣裙]: 2397
# [imgtrain/ 印花a字裙]: 2400
# [imgtrain/ 修身包臀裙]: 2400
# [imgtrain/ 名媛连衣裙]: 2400
# [imgtrain/ 大码a字裙]: 2400
# [imgtrain/ 短袖旗袍]: 2396
# [imgtrain/ 印花连衣裙]: 2400
# [imgtrain/ 修身长裙]: 2401
# [imgtrain/ 羊毛连衣裙]: 2400
# [imgtrain/ 女童连衣裙]: 2372
# [imgtrain/ 包臀连衣裙]: 2392
# [imgtrain/ 吊带长裙]: 1304
# [imgtrain/ 碎花裙子]: 2384
# [imgtrain/ 长袖长裙]: 2356
# [imgtrain/ 不规则连衣裙]: 2402
# [imgtrain/ 百褶连衣裙]: 2402
# [imgtrain/ 印花长裙]: 2380
# [imgtrain/ 褶皱连衣裙]: 2062
# [imgtrain/ 修身连衣裙]: 2392
# [imgtrain/ 短袖连衣裙]: 2400
# [imgtrain/ 网纱连衣裙]: 2395
# [imgtrain/ 两件套连衣裙]: 2400
# [imgtrain/ 网纱公主裙]: 2400
# [imgtrain/ 一字肩连衣裙]: 2402
# [imgtrain/ 大码雪纺连衣裙]: 2400
# [imgtrain/ 加厚连衣裙]: 2402
# [imgtrain/ 打底背心裙]: 2400
# [imgtrain/ 方领连衣裙]: 2400
# [imgtrain/ 大码旗袍]: 2403
# [imgtrain/ 紧身连衣裙]: 2400
# [imgtrain/ 桑蚕丝旗袍]: 2400
# [imgtrain/ 无袖连衣裙]: 2395
# [imgtrain/ 欧根纱连衣裙]: 2389
# [imgtrain/ 波西米亚沙滩裙]: 1642
# [imgtrain/ 民族风连衣裙]: 2288
# [imgtrain/ 修身短裙]: 2401
# [imgtrain/ 牛仔背带裙]: 2209
# [imgtrain/ 打底毛衣裙]: 1640
# [imgtrain/ 性感连衣裙]: 2404
# [imgtrain/ 儿童背心裙]: 2400
# [imgtrain/ 潮连衣裙]: 2398
# [imgtrain/ 雪纺连衣裙]: 2399
# [imgtrain/ 蝴蝶结连衣裙]: 2402
# [imgtrain/ 长袖打底裙]: 2383
# [imgtrain/ 打底连衣裙]: 2379
# [imgtrain/ 民族风长裙]: 2400
# [imgtrain/ 吊带连衣裙]: 2388
# [imgtrain/ 网纱裙子]: 2391
# [imgtrain/ 网纱蓬蓬裙]: 2401
# [imgtrain/ 修身a字裙]: 2400
# [imgtrain/ 假两件长袖连衣裙]: 2394
# [imgtrain/ 丝麻连衣裙]: 2396
# [imgtrain/ 修身裙子]: 2399
# [imgtrain/ chic连衣裙]: 2398
# [imgtrain/ 马甲连衣裙]: 2399
# [imgtrain/ 加厚打底裙]: 2400
# [imgtrain/ 度假沙滩裙]: 2368
# [imgtrain/ 女童裙子]: 2376
# [imgtrain/ 长袖针织连衣裙]: 2392
# [imgtrain/ 无袖背心裙]: 1142
# [imgtrain/ 中国风连衣裙]: 2398
# [imgtrain/ 花色连衣裙]: 2352
# [imgtrain/ 复古裙子]: 2400
# [imgtrain/ 亮片连衣裙]: 2390
# [imgtrain/ 保暖连衣裙]: 2400
# [imgtrain/ 雪纺长裙]: 2400
# [imgtrain/ 蕾丝打底裙]: 2407
# [imgtrain/ 名媛裙子]: 2395
# [imgtrain/ 卡通连衣裙]: 2397
# [imgtrain/ 长袖包臀连衣裙]: 2399
# [imgtrain/ 打底长袖连衣裙]: 2398
# [imgtrain/ 复古长裙]: 2402
# [imgtrain/ a型连衣裙]: 2401
# [imgtrain/ 灯芯绒连衣裙]: 2400
# [imgtrain/ 波西米亚连衣裙]: 2388
# [imgtrain/ 打底a字裙]: 2404
# [imgtrain/ 条纹连衣裙]: 2403
# [imgtrain/ 开叉长裙]: 2401
# [imgtrain/ 挂脖连衣裙]: 2400
# [imgtrain/ 丝绸旗袍]: 1970
# [imgtrain/ 印花真丝连衣裙]: 2357
# [imgtrain/ 刺绣长裙]: 2400
# [imgtrain/ 印花长袖连衣裙]: 2400
# [imgtrain/ 长袖宽松连衣裙]: 2398
# [imgtrain/ 长袖圆领连衣裙]: 1694
# [imgtrain/ 不规则裙]: 2400
# [imgtrain/ 衬衫连衣裙]: 2400
# [imgtrain/ 高领针织连衣裙]: 2398
# [imgtrain/ 蕾丝长裙]: 2399
# [imgtrain/ 格子连衣裙]: 2401
# [imgtrain/ 荷叶边连衣裙]: 2401
# [imgtrain/ 压褶连衣裙]: 2400
# [imgtrain/ 童装连衣裙]: 2399
# [imgtrain/ 大码印花连衣裙]: 2398
# [imgtrain/ 羊绒连衣裙]: 2401
# [imgtrain/ 喇叭袖连衣裙]: 2403
# [imgtrain/ 荷叶袖连衣裙]: 2400
# [imgtrain/ 儿童演出服]: 2401
# [imgtrain/ 大码裙子]: 2388
# [imgtrain/ 沙滩长裙]: 2396
# [imgtrain/ 背心连衣裙]: 2401
# [imgtrain/ 牛仔连衣裙子]: 1071
# [imgtrain/ 吊带背心裙]: 2396
# [imgtrain/ 蕾丝花边]: 1436
# [imgtrain/ 花边连衣裙]: 2382
# [imgtrain/ v领连衣裙]: 2398
# [imgtrain/ 露背连衣裙]: 2400
# [imgtrain/ 弹力连衣裙]: 2335
# [imgtrain/ 一字领连衣裙]: 2400
# [imgtrain/ 打底裙子]: 2400
# [imgtrain/ 长袖公主裙]: 2400
# [imgtrain/ 雪纺裙子]: 2399
# [imgtrain/ 长袖中裙]: 2400
# [imgtrain/ 吊带裙子]: 2396
# [imgtrain/ 长袖a字裙]: 2400
# [imgtrain/ 绣花连衣裙]: 2392
# [imgtrain/ 无袖公主裙]: 2396
# [imgtrain/ 蕾丝旗袍]: 2401
# [imgtrain/ 条纹长袖连衣裙]: 2399
# [imgtrain/ 性感包臀连衣裙]: 2400
# [imgtrain/ 蕾丝裙子]: 2399
# [imgtrain/ 包臀短裙]: 2403
# [imgtrain/ 苎麻连衣裙]: 2399
# [imgtrain/ 鱼尾连衣裙]: 2399
# [imgtrain/ 迷你连衣裙]: 2398
# [imgtrain/ 单排扣连衣裙]: 2401
# [imgtrain/ 真丝连衣裙]: 2269
# [imgtrain/ 大码长裙]: 2395
# [imgval/ 蝴蝶结长袖连衣裙]: 807
# [imgval/ 包臀长袖连衣裙]: 300
# [imgval/ 假两件连衣裙]: 301
# [imgval/ 修身包臀连衣裙]: 300
# [imgval/ 女童背心裙]: 301
# [imgval/ 刺绣连衣裙]: 300
# [imgval/ 修身打底连衣裙]: 301
# [imgval/ 礼服长裙]: 300
# [imgval/ 包臀鱼尾裙]: 301
# [imgval/ 提花连衣裙]: 296
# [imgval/ 民族风旗袍]: 301
# [imgval/ 字母连衣裙]: 301
# [imgval/ 大码宽松连衣裙]: 301
# [imgval/ 桑蚕丝裙子]: 301
# [imgval/ 高腰连衣裙]: 301
# [imgval/ 圆点连衣裙]: 301
# [imgval/ 公主蓬蓬裙]: 300
# [imgval/ 假两件裙子]: 301
# [imgval/ 蕾丝连衣裙]: 300
# [imgval/ 勾花连衣裙]: 300
# [imgval/ 大码短袖连衣裙]: 301
# [imgval/ 松紧腰连衣裙]: 301
# [imgval/ 半身裙套装]: 300
# [imgval/ 连衣裙两件套]: 301
# [imgval/ 复古旗袍]: 299
# [imgval/ 网纱长裙]: 301
# [imgval/ 潮流连衣裙]: 301
# [imgval/ 包臀针织连衣裙]: 301
# [imgval/ 连帽连衣裙]: 300
# [imgval/ 品牌连衣裙]: 300
# [imgval/ 无袖长裙]: 301
# [imgval/ 长袖针织衫]: 301
# [imgval/ 牛仔连衣裙]: 301
# [imgval/ 两件套装裙]: 301
# [imgval/ 修身打底裙]: 300
# [imgval/ 女童礼服]: 301
# [imgval/ 女童长袖连衣裙]: 301
# [imgval/ 套头连衣裙]: 302
# [imgval/ 简约连衣裙]: 301
# [imgval/ 蕾丝打底连衣裙]: 301
# [imgval/ 立领连衣裙]: 132
# [imgval/ 绑带连衣裙]: 301
# [imgval/ 圆领连衣裙]: 301
# [imgval/ 长袖连衣裙]: 301
# [imgval/ 短款旗袍]: 300
# [imgval/ 刺绣旗袍]: 301
# [imgval/ 桑蚕丝连衣裙]: 301
# [imgval/ 绷带连衣裙]: 301
# [imgval/ 圆领a字裙]: 301
# [imgval/ 休闲连衣裙]: 301
# [imgval/ 短袖长裙]: 303
# [imgval/ 长袖印花连衣裙]: 298
# [imgval/ 宽松连衣裙]: 301
# [imgval/ 吊带两件套]: 301
# [imgval/ 波点连衣裙]: 295
# [imgval/ 女童旗袍]: 301
# [imgval/ 印花裙子]: 298
# [imgval/ 女童公主裙]: 301
# [imgval/ 蕾丝公主裙]: 301
# [imgval/ 钉珠连衣裙]: 301
# [imgval/ 复古连衣裙]: 271
# [imgval/ 女童礼服裙]: 301
# [imgval/ 镂空连衣裙]: 301
# [imgval/ 波西米亚长裙]: 300
# [imgval/ 公主连衣裙]: 301
# [imgval/ 沙滩连衣裙]: 301
# [imgval/ 露肩连衣裙]: 300
# [imgval/ 翻领连衣裙]: 301
# [imgval/ 大码连衣裙]: 300
# [imgval/ 花朵连衣裙]: 300
# [imgval/ 碎花连衣裙]: 264
# [imgval/ 哺乳连衣裙]: 300
# [imgval/ 灯笼袖连衣裙]: 301
# [imgval/ 公主裙子]: 301
# [imgval/ 加厚打底连衣裙]: 301
# [imgval/ 大码长袖连衣裙]: 301
# [imgval/ 印花a字裙]: 300
# [imgval/ 修身包臀裙]: 301
# [imgval/ 名媛连衣裙]: 300
# [imgval/ 大码a字裙]: 301
# [imgval/ 短袖旗袍]: 301
# [imgval/ 印花连衣裙]: 300
# [imgval/ 修身长裙]: 301
# [imgval/ 羊毛连衣裙]: 301
# [imgval/ 女童连衣裙]: 298
# [imgval/ 包臀连衣裙]: 299
# [imgval/ 吊带长裙]: 163
# [imgval/ 碎花裙子]: 299
# [imgval/ 长袖长裙]: 296
# [imgval/ 不规则连衣裙]: 301
# [imgval/ 百褶连衣裙]: 301
# [imgval/ 印花长裙]: 298
# [imgval/ 褶皱连衣裙]: 259
# [imgval/ 修身连衣裙]: 299
# [imgval/ 短袖连衣裙]: 301
# [imgval/ 网纱连衣裙]: 300
# [imgval/ 两件套连衣裙]: 300
# [imgval/ 网纱公主裙]: 301
# [imgval/ 一字肩连衣裙]: 301
# [imgval/ 大码雪纺连衣裙]: 301
# [imgval/ 加厚连衣裙]: 301
# [imgval/ 打底背心裙]: 301
# [imgval/ 方领连衣裙]: 300
# [imgval/ 大码旗袍]: 301
# [imgval/ 紧身连衣裙]: 301
# [imgval/ 桑蚕丝旗袍]: 301
# [imgval/ 无袖连衣裙]: 300
# [imgval/ 欧根纱连衣裙]: 300
# [imgval/ 波西米亚沙滩裙]: 206
# [imgval/ 民族风连衣裙]: 287
# [imgval/ 修身短裙]: 301
# [imgval/ 牛仔背带裙]: 277
# [imgval/ 打底毛衣裙]: 206
# [imgval/ 性感连衣裙]: 301
# [imgval/ 儿童背心裙]: 300
# [imgval/ 潮连衣裙]: 301
# [imgval/ 雪纺连衣裙]: 301
# [imgval/ 蝴蝶结连衣裙]: 301
# [imgval/ 长袖打底裙]: 299
# [imgval/ 打底连衣裙]: 298
# [imgval/ 民族风长裙]: 301
# [imgval/ 吊带连衣裙]: 300
# [imgval/ 网纱裙子]: 300
# [imgval/ 网纱蓬蓬裙]: 301
# [imgval/ 修身a字裙]: 300
# [imgval/ 假两件长袖连衣裙]: 300
# [imgval/ 丝麻连衣裙]: 301
# [imgval/ 修身裙子]: 301
# [imgval/ chic连衣裙]: 301
# [imgval/ 马甲连衣裙]: 301
# [imgval/ 加厚打底裙]: 300
# [imgval/ 度假沙滩裙]: 296
# [imgval/ 女童裙子]: 298
# [imgval/ 长袖针织连衣裙]: 299
# [imgval/ 无袖背心裙]: 144
# [imgval/ 中国风连衣裙]: 301
# [imgval/ 花色连衣裙]: 294
# [imgval/ 复古裙子]: 301
# [imgval/ 亮片连衣裙]: 300
# [imgval/ 保暖连衣裙]: 301
# [imgval/ 雪纺长裙]: 301
# [imgval/ 蕾丝打底裙]: 302
# [imgval/ 名媛裙子]: 300
# [imgval/ 卡通连衣裙]: 301
# [imgval/ 长袖包臀连衣裙]: 301
# [imgval/ 打底长袖连衣裙]: 301
# [imgval/ 复古长裙]: 301
# [imgval/ a型连衣裙]: 301
# [imgval/ 灯芯绒连衣裙]: 300
# [imgval/ 波西米亚连衣裙]: 300
# [imgval/ 打底a字裙]: 302
# [imgval/ 条纹连衣裙]: 301
# [imgval/ 开叉长裙]: 301
# [imgval/ 挂脖连衣裙]: 301
# [imgval/ 丝绸旗袍]: 247
# [imgval/ 印花真丝连衣裙]: 296
# [imgval/ 刺绣长裙]: 300
# [imgval/ 印花长袖连衣裙]: 300
# [imgval/ 长袖宽松连衣裙]: 301
# [imgval/ 长袖圆领连衣裙]: 213
# [imgval/ 不规则裙]: 300
# [imgval/ 衬衫连衣裙]: 300
# [imgval/ 高领针织连衣裙]: 301
# [imgval/ 蕾丝长裙]: 301
# [imgval/ 格子连衣裙]: 301
# [imgval/ 荷叶边连衣裙]: 301
# [imgval/ 压褶连衣裙]: 300
# [imgval/ 童装连衣裙]: 301
# [imgval/ 大码印花连衣裙]: 301
# [imgval/ 羊绒连衣裙]: 301
# [imgval/ 喇叭袖连衣裙]: 301
# [imgval/ 荷叶袖连衣裙]: 300
# [imgval/ 儿童演出服]: 301
# [imgval/ 大码裙子]: 299
# [imgval/ 沙滩长裙]: 300
# [imgval/ 背心连衣裙]: 301
# [imgval/ 牛仔连衣裙子]: 134
# [imgval/ 吊带背心裙]: 300
# [imgval/ 蕾丝花边]: 181
# [imgval/ 花边连衣裙]: 299
# [imgval/ v领连衣裙]: 301
# [imgval/ 露背连衣裙]: 301
# [imgval/ 弹力连衣裙]: 293
# [imgval/ 一字领连衣裙]: 301
# [imgval/ 打底裙子]: 301
# [imgval/ 长袖公主裙]: 300
# [imgval/ 雪纺裙子]: 301
# [imgval/ 长袖中裙]: 300
# [imgval/ 吊带裙子]: 300
# [imgval/ 长袖a字裙]: 300
# [imgval/ 绣花连衣裙]: 300
# [imgval/ 无袖公主裙]: 301
# [imgval/ 蕾丝旗袍]: 301
# [imgval/ 条纹长袖连衣裙]: 301
# [imgval/ 性感包臀连衣裙]: 300
# [imgval/ 蕾丝裙子]: 301
# [imgval/ 包臀短裙]: 301
# [imgval/ 苎麻连衣裙]: 301
# [imgval/ 鱼尾连衣裙]: 301
# [imgval/ 迷你连衣裙]: 301
# [imgval/ 单排扣连衣裙]: 301
# [imgval/ 真丝连衣裙]: 285
# [imgval/ 大码长裙]: 300
# [imgtest/ 蝴蝶结长袖连衣裙]: 810
# [imgtest/ 包臀长袖连衣裙]: 300
# [imgtest/ 假两件连衣裙]: 300
# [imgtest/ 修身包臀连衣裙]: 300
# [imgtest/ 女童背心裙]: 299
# [imgtest/ 刺绣连衣裙]: 299
# [imgtest/ 修身打底连衣裙]: 299
# [imgtest/ 礼服长裙]: 300
# [imgtest/ 包臀鱼尾裙]: 300
# [imgtest/ 提花连衣裙]: 294
# [imgtest/ 民族风旗袍]: 301
# [imgtest/ 字母连衣裙]: 300
# [imgtest/ 大码宽松连衣裙]: 300
# [imgtest/ 桑蚕丝裙子]: 300
# [imgtest/ 高腰连衣裙]: 300
# [imgtest/ 圆点连衣裙]: 300
# [imgtest/ 公主蓬蓬裙]: 300
# [imgtest/ 假两件裙子]: 299
# [imgtest/ 蕾丝连衣裙]: 300
# [imgtest/ 勾花连衣裙]: 300
# [imgtest/ 大码短袖连衣裙]: 299
# [imgtest/ 松紧腰连衣裙]: 299
# [imgtest/ 半身裙套装]: 300
# [imgtest/ 连衣裙两件套]: 300
# [imgtest/ 复古旗袍]: 299
# [imgtest/ 网纱长裙]: 300
# [imgtest/ 潮流连衣裙]: 300
# [imgtest/ 包臀针织连衣裙]: 299
# [imgtest/ 连帽连衣裙]: 300
# [imgtest/ 品牌连衣裙]: 300
# [imgtest/ 无袖长裙]: 300
# [imgtest/ 长袖针织衫]: 300
# [imgtest/ 牛仔连衣裙]: 300
# [imgtest/ 两件套装裙]: 300
# [imgtest/ 修身打底裙]: 299
# [imgtest/ 女童礼服]: 299
# [imgtest/ 女童长袖连衣裙]: 300
# [imgtest/ 套头连衣裙]: 300
# [imgtest/ 简约连衣裙]: 299
# [imgtest/ 蕾丝打底连衣裙]: 300
# [imgtest/ 立领连衣裙]: 130
# [imgtest/ 绑带连衣裙]: 300
# [imgtest/ 圆领连衣裙]: 300
# [imgtest/ 长袖连衣裙]: 300
# [imgtest/ 短款旗袍]: 299
# [imgtest/ 刺绣旗袍]: 300
# [imgtest/ 桑蚕丝连衣裙]: 300
# [imgtest/ 绷带连衣裙]: 299
# [imgtest/ 圆领a字裙]: 300
# [imgtest/ 休闲连衣裙]: 300
# [imgtest/ 短袖长裙]: 301
# [imgtest/ 长袖印花连衣裙]: 296
# [imgtest/ 宽松连衣裙]: 300
# [imgtest/ 吊带两件套]: 300
# [imgtest/ 波点连衣裙]: 294
# [imgtest/ 女童旗袍]: 299
# [imgtest/ 印花裙子]: 296
# [imgtest/ 女童公主裙]: 301
# [imgtest/ 蕾丝公主裙]: 300
# [imgtest/ 钉珠连衣裙]: 300
# [imgtest/ 复古连衣裙]: 270
# [imgtest/ 女童礼服裙]: 300
# [imgtest/ 镂空连衣裙]: 300
# [imgtest/ 波西米亚长裙]: 298
# [imgtest/ 公主连衣裙]: 300
# [imgtest/ 沙滩连衣裙]: 300
# [imgtest/ 露肩连衣裙]: 300
# [imgtest/ 翻领连衣裙]: 300
# [imgtest/ 大码连衣裙]: 299
# [imgtest/ 花朵连衣裙]: 300
# [imgtest/ 碎花连衣裙]: 262
# [imgtest/ 哺乳连衣裙]: 298
# [imgtest/ 灯笼袖连衣裙]: 300
# [imgtest/ 公主裙子]: 299
# [imgtest/ 加厚打底连衣裙]: 300
# [imgtest/ 大码长袖连衣裙]: 299
# [imgtest/ 印花a字裙]: 300
# [imgtest/ 修身包臀裙]: 300
# [imgtest/ 名媛连衣裙]: 300
# [imgtest/ 大码a字裙]: 300
# [imgtest/ 短袖旗袍]: 299
# [imgtest/ 印花连衣裙]: 300
# [imgtest/ 修身长裙]: 300
# [imgtest/ 羊毛连衣裙]: 300
# [imgtest/ 女童连衣裙]: 296
# [imgtest/ 包臀连衣裙]: 299
# [imgtest/ 吊带长裙]: 163
# [imgtest/ 碎花裙子]: 298
# [imgtest/ 长袖长裙]: 294
# [imgtest/ 不规则连衣裙]: 300
# [imgtest/ 百褶连衣裙]: 300
# [imgtest/ 印花长裙]: 297
# [imgtest/ 褶皱连衣裙]: 257
# [imgtest/ 修身连衣裙]: 299
# [imgtest/ 短袖连衣裙]: 300
# [imgtest/ 网纱连衣裙]: 299
# [imgtest/ 两件套连衣裙]: 300
# [imgtest/ 网纱公主裙]: 300
# [imgtest/ 一字肩连衣裙]: 300
# [imgtest/ 大码雪纺连衣裙]: 300
# [imgtest/ 加厚连衣裙]: 300
# [imgtest/ 打底背心裙]: 300
# [imgtest/ 方领连衣裙]: 300
# [imgtest/ 大码旗袍]: 300
# [imgtest/ 紧身连衣裙]: 300
# [imgtest/ 桑蚕丝旗袍]: 300
# [imgtest/ 无袖连衣裙]: 299
# [imgtest/ 欧根纱连衣裙]: 298
# [imgtest/ 波西米亚沙滩裙]: 205
# [imgtest/ 民族风连衣裙]: 286
# [imgtest/ 修身短裙]: 300
# [imgtest/ 牛仔背带裙]: 276
# [imgtest/ 打底毛衣裙]: 205
# [imgtest/ 性感连衣裙]: 300
# [imgtest/ 儿童背心裙]: 300
# [imgtest/ 潮连衣裙]: 299
# [imgtest/ 雪纺连衣裙]: 299
# [imgtest/ 蝴蝶结连衣裙]: 300
# [imgtest/ 长袖打底裙]: 297
# [imgtest/ 打底连衣裙]: 297
# [imgtest/ 民族风长裙]: 300
# [imgtest/ 吊带连衣裙]: 298
# [imgtest/ 网纱裙子]: 298
# [imgtest/ 网纱蓬蓬裙]: 300
# [imgtest/ 修身a字裙]: 300
# [imgtest/ 假两件长袖连衣裙]: 299
# [imgtest/ 丝麻连衣裙]: 299
# [imgtest/ 修身裙子]: 299
# [imgtest/ chic连衣裙]: 299
# [imgtest/ 马甲连衣裙]: 299
# [imgtest/ 加厚打底裙]: 300
# [imgtest/ 度假沙滩裙]: 296
# [imgtest/ 女童裙子]: 297
# [imgtest/ 长袖针织连衣裙]: 299
# [imgtest/ 无袖背心裙]: 142
# [imgtest/ 中国风连衣裙]: 299
# [imgtest/ 花色连衣裙]: 294
# [imgtest/ 复古裙子]: 300
# [imgtest/ 亮片连衣裙]: 298
# [imgtest/ 保暖连衣裙]: 300
# [imgtest/ 雪纺长裙]: 300
# [imgtest/ 蕾丝打底裙]: 300
# [imgtest/ 名媛裙子]: 299
# [imgtest/ 卡通连衣裙]: 299
# [imgtest/ 长袖包臀连衣裙]: 299
# [imgtest/ 打底长袖连衣裙]: 299
# [imgtest/ 复古长裙]: 300
# [imgtest/ a型连衣裙]: 300
# [imgtest/ 灯芯绒连衣裙]: 300
# [imgtest/ 波西米亚连衣裙]: 298
# [imgtest/ 打底a字裙]: 300
# [imgtest/ 条纹连衣裙]: 300
# [imgtest/ 开叉长裙]: 300
# [imgtest/ 挂脖连衣裙]: 300
# [imgtest/ 丝绸旗袍]: 246
# [imgtest/ 印花真丝连衣裙]: 294
# [imgtest/ 刺绣长裙]: 300
# [imgtest/ 印花长袖连衣裙]: 300
# [imgtest/ 长袖宽松连衣裙]: 299
# [imgtest/ 长袖圆领连衣裙]: 211
# [imgtest/ 不规则裙]: 300
# [imgtest/ 衬衫连衣裙]: 300
# [imgtest/ 高领针织连衣裙]: 299
# [imgtest/ 蕾丝长裙]: 299
# [imgtest/ 格子连衣裙]: 300
# [imgtest/ 荷叶边连衣裙]: 300
# [imgtest/ 压褶连衣裙]: 300
# [imgtest/ 童装连衣裙]: 299
# [imgtest/ 大码印花连衣裙]: 299
# [imgtest/ 羊绒连衣裙]: 300
# [imgtest/ 喇叭袖连衣裙]: 300
# [imgtest/ 荷叶袖连衣裙]: 300
# [imgtest/ 儿童演出服]: 300
# [imgtest/ 大码裙子]: 298
# [imgtest/ 沙滩长裙]: 299
# [imgtest/ 背心连衣裙]: 300
# [imgtest/ 牛仔连衣裙子]: 134
# [imgtest/ 吊带背心裙]: 299
# [imgtest/ 蕾丝花边]: 179
# [imgtest/ 花边连衣裙]: 297
# [imgtest/ v领连衣裙]: 299
# [imgtest/ 露背连衣裙]: 300
# [imgtest/ 弹力连衣裙]: 291
# [imgtest/ 一字领连衣裙]: 300
# [imgtest/ 打底裙子]: 300
# [imgtest/ 长袖公主裙]: 300
# [imgtest/ 雪纺裙子]: 299
# [imgtest/ 长袖中裙]: 300
# [imgtest/ 吊带裙子]: 299
# [imgtest/ 长袖a字裙]: 300
# [imgtest/ 绣花连衣裙]: 299
# [imgtest/ 无袖公主裙]: 299
# [imgtest/ 蕾丝旗袍]: 300
# [imgtest/ 条纹长袖连衣裙]: 299
# [imgtest/ 性感包臀连衣裙]: 300
# [imgtest/ 蕾丝裙子]: 299
# [imgtest/ 包臀短裙]: 300
# [imgtest/ 苎麻连衣裙]: 299
# [imgtest/ 鱼尾连衣裙]: 299
# [imgtest/ 迷你连衣裙]: 299
# [imgtest/ 单排扣连衣裙]: 300
# [imgtest/ 真丝连衣裙]: 283
# [imgtest/ 大码长裙]: 299

# %% [markdown]
# #### Distribution of Errors for each Class

# %%
# Input class index, partition set and photo index, output an image display
# [partition_idx] train: 1, val: 2, test: 3
def jpg_query(class_idx, partition_idx, file_idx, vis = True, print_path = False):
    # Set up target path
    class_type = CLASS_MAP[class_idx]
    partition_type = PARTITION_MAP[partition_idx]
    sub_target_path = SOURCE_PATH + partition_type + '/' + class_type
    target_filename = os.listdir(sub_target_path)[file_idx]
    target_path = sub_target_path + '/' + target_filename
    if print_path:
        print('Path: %s' % target_path)
    
    img = Image.open(target_path)
    if vis: 
    # Display image
        plt.imshow(img);
        print(np.asarray(img, dtype=np.uint8).shape)
    # np.unit8 = 2**8
    return np.asarray(img, dtype=np.uint8).shape

# %%
def is_error(class_idx, partition_idx, file_idx):
    dim = jpg_query(class_idx, partition_idx, file_idx, vis = False, print_path = False)
    if len(dim) == 3:
        is_error_ = 0
    else:
        is_error_ = 1
    return (partition_idx, class_idx, file_idx), is_error_

# %%
# Create input list for multiprocess
input_list = []
for partition_idx, partition_type in PARTITION_MAP.items():
    for class_idx, class_type in CLASS_MAP.items():
        jpg_num = dist_dict[partition_idx][class_idx]
        for i in range(jpg_num):
            tmp_tuple = (class_idx, partition_idx, i)
            input_list.append(tmp_tuple)
input_list = tuple(input_list)

# %%
# Multi-processing
import time
import multiprocess as mp

start_time = time.time()
p = mp.Pool(processes = 60)

with p as pool:
    results = p.starmap(is_error, input_list)

p.close()
p.join()
print("---Multiprocess Complete: %d mins ---" % ((time.time() - start_time)/60))
# Out:
# ---Multiprocess Complete: 6 mins ---

# %%
import pandas as pd
error_df = pd.DataFrame(results, columns=['index', 'error'])
error_df[['partition_idx', 'class_idx', 'file_idx']] = error_df['index'].apply(pd.Series)

# %%
error_df.groupby('class_idx')['error'].agg('sum').sort_values().head(10)
# Out:
# class_idx
# 56     0
# 173    0
# 44     0
# 47     0
# 171    0
# 49     0
# 51     0
# 52     0
# 55     0
# 139    0
# Name: error, dtype: int64

# %% [markdown]
# #### Select A Few Classes with No Errors

# %%
GOOD_CLASS_MAP = {}
GOOD_CLASS_MAP[56] = CLASS_MAP[56]
GOOD_CLASS_MAP[173] = CLASS_MAP[173]
GOOD_CLASS_MAP[44] = CLASS_MAP[44]
GOOD_CLASS_MAP[47] = CLASS_MAP[47]
GOOD_CLASS_MAP[171] = CLASS_MAP[171]

# %%
GOOD_CLASS_MAPASS_MAPASS_MAP
# Out:
# {56: '印花裙子', 173: '大码裙子', 44: '短款旗袍', 47: '绷带连衣裙', 171: '荷叶袖连衣裙'}

# %% [markdown]
# ##### Selected Class for Sample Run
# 1. '印花裙子'
# 2. '大码裙子'
# 3. '短款旗袍'
# 4. '绷带连衣裙'
# 5. '荷叶袖连衣裙'

# %% [markdown]
# #### Distribution of Partition for Selected Classes

# %%
# Find the distribution of selected classes
dist_dict = defaultdict(dict)
for partition_idx, folder in PARTITION_MAP.items():
    for class_idx, class_ in GOOD_CLASS_MAP.items():
        target_path = SOURCE_PATH + folder +'/' + class_
        cnt = len([item for item in os.listdir(target_path) if 'jpg' in item])
        dist_dict[partition_idx][class_idx] = cnt
        print('[%s/ %s]: %d' % (folder, class_, cnt))
# Out:
# [imgtrain/ 印花裙子]: 2375
# [imgtrain/ 大码裙子]: 2388
# [imgtrain/ 短款旗袍]: 2396
# [imgtrain/ 绷带连衣裙]: 2398
# [imgtrain/ 荷叶袖连衣裙]: 2400
# [imgval/ 印花裙子]: 298
# [imgval/ 大码裙子]: 299
# [imgval/ 短款旗袍]: 300
# [imgval/ 绷带连衣裙]: 301
# [imgval/ 荷叶袖连衣裙]: 300
# [imgtest/ 印花裙子]: 296
# [imgtest/ 大码裙子]: 298
# [imgtest/ 短款旗袍]: 299
# [imgtest/ 绷带连衣裙]: 299
# [imgtest/ 荷叶袖连衣裙]: 300

# %% [markdown]
# #### Migrate Data of Selected Classes

# %%
os.getcwd()
# Out:
# '/home/r8user2/Documents/HY/dress_data/alex_workplace/dressdata_project'

# %%
path = 'git_workplace/selected_gd_data10'
os.mkdir(path)

# %%
for partition_idx, partition_type in PARTITION_MAP.items():
    os.mkdir(path + '/' + partition_type)
    for class_idx, class_type in GOOD_CLASS_MAP.items():
        os.mkdir(path + '/' + partition_type + '/' + class_type)

# %%
import shutil
def copytree(src, dst, symlinks=False, ignore=None):
    for item in os.listdir(src):
        s = os.path.join(src, item)
        d = os.path.join(dst, item)
        if os.path.isdir(s):
            shutil.copytree(s, d, symlinks, ignore)
        else:
            shutil.copy2(s, d)

# %%
for partition_idx, partition_type in PARTITION_MAP.items():
    for class_idx, class_type in GOOD_CLASS_MAP.items():
        from_path = SOURCE_PATH + partition_type + '/' + class_type
        to_path = path + '/' + partition_type + '/' + class_type
        copytree(from_path, to_path)
        print(to_path)
# Out:
# git_workplace/data/imgtrain/印花裙子
# git_workplace/data/imgtrain/大码裙子
# git_workplace/data/imgtrain/短款旗袍
# git_workplace/data/imgtrain/绷带连衣裙
# git_workplace/data/imgtrain/荷叶袖连衣裙
# git_workplace/data/imgval/印花裙子
# git_workplace/data/imgval/大码裙子
# git_workplace/data/imgval/短款旗袍
# git_workplace/data/imgval/绷带连衣裙
# git_workplace/data/imgval/荷叶袖连衣裙
# git_workplace/data/imgtest/印花裙子
# git_workplace/data/imgtest/大码裙子
# git_workplace/data/imgtest/短款旗袍
# git_workplace/data/imgtest/绷带连衣裙
# git_workplace/data/imgtest/荷叶袖连衣裙

# %%
os.getcwd()
# Out:
# '/home/r8user2/Documents/HY/dress_data/alex_workplace/dressdata_project'
